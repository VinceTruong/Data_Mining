# %% [markdown]
# <a href="https://colab.research.google.com/github/VinceTruong/Data_Mining/blob/Thanh/Facial_Emotion_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/VinceTruong/Data_Mining.git
# Out:
# Cloning into 'Data_Mining'...
# remote: Enumerating objects: 34053, done.
# remote: Total 34053 (delta 0), reused 0 (delta 0), pack-reused 34053
# Receiving objects: 100% (34053/34053), 52.45 MiB | 29.43 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (35887/35887), done.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.listdir("/content/Data_Mining/dataset/train")
# Out:
# ['sad', 'surprise', 'fear', 'happy', 'disgust', 'neutral', 'angry']

# %%
train_path = "/content/Data_Mining/dataset/train"
test_path = "/content/Data_Mining/dataset/test"

# %%
os.listdir(train_path)
# Out:
# ['sad', 'surprise', 'fear', 'happy', 'disgust', 'neutral', 'angry']

# %%
emotion_labels = sorted (os.listdir(train_path))
print (emotion_labels)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Importing TensorFlow libraries
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import Sequential
from tensorflow import keras
from sklearn.model_selection import KFold

# %%
batch_size = 64
target_size = (48, 48)

train_datagen = ImageDataGenerator (rescale = 1/255)
test_datagen = ImageDataGenerator (rescale = 1/255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True)

test_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
train_generator

# %% [markdown]
# ##**Show picture with labels**

# %%
img_path = []
for emotion in emotion_labels:
  for i in range (5):
    img_dir = os.listdir(f'{train_path}/{emotion}')[i]
    image = plt.imread(f'{train_path}/{emotion}/{img_dir}')
    img_path.append (image)

# %%
plt.figure (figsize = (20, 30))
for x, y in enumerate (img_path):
  plt.subplot (7, 5, x+1)
  plt.xlabel (sorted (emotion_labels*5)[x])
  plt.imshow (y, cmap = 'gray')

# %%
input_shape = (48, 48, 1)
num_classes = 7

# %%
type(os.listdir ('/content/Data_Mining/dataset/train/surprise'))
# Out:
# list

# %%
import matplotlib.pyplot as plt

# %%
plt.tight_layout()

# %%
plt.imshow(plt.imread(train_path+"/surprise/Training_9076216.jpg"), cmap = 'gray')

# %%
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
  
    plt.figure(figsize=(12, 12))
    return (img_files)
    '''for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')'''

# %%
plot_images (train_path +'/angry')
# Out:
# ['/content/Data_Mining/dataset/train/angry/Training_89962650.jpg',
#  '/content/Data_Mining/dataset/train/angry/Training_95997783.jpg',
#  '/content/Data_Mining/dataset/train/angry/Training_77885235.jpg',
#  '/content/Data_Mining/dataset/train/angry/Training_11713762.jpg',
#  '/content/Data_Mining/dataset/train/angry/Training_23150659.jpg']

# %%
plot_images (train_path+'/angry').img_files
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-f4d7a96ed43f> in <module>
# ----> 1 plot_images (train_path+'/angry').img_files
#
# AttributeError: 'NoneType' object has no attribute 'img_files'
